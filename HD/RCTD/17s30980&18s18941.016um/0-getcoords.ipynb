# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
left  = sc.read('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/3-analysis/adata_016um_left.h5ad')
# Out:
# /home/tangzhixuan/miniconda3/envs/myen/lib/python3.10/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
right  = sc.read('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/3-analysis/adata_016um_right.h5ad')
# Out:
# /home/tangzhixuan/miniconda3/envs/myen/lib/python3.10/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
right.var_names_make_unique()
left.var_names_make_unique()

# %%
adata = sc.concat(
    [right, left],
    label="batch",  # 在 obs 中添加批次列
    keys=["18s18941", "17s30980"]  # 批次名称
)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 141687 × 18085
#     obs: 'in_tissue', 'array_row', 'array_col', 'pxl_row_in_fullres', 'pxl_col_in_fullres', 'index', 'tissue', 'batch'
#     obsm: 'spatial'

# %%
adata = sc.concat

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 77526 × 18085
#     obs: 'in_tissue', 'array_row', 'array_col', 'pxl_row_in_fullres', 'pxl_col_in_fullres', 'index'
#     var: 'gene_ids', 'feature_types', 'genome'
#     obsm: 'spatial'

# %%
adata.write('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/0-Rawh5ad/17s30980&18s18941.016um.h5ad')

# %%
(pd.DataFrame(adata.obsm['spatial'],columns = ['x','y'],index = adata.obs.index)).to_csv('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/2-RCTD/17s30980&18s18941.016um/17s30980&18s18941.016um.coords.csv')

# %%
adata = sc.read('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/0-Rawh5ad/17s30980&18s18941.016um.h5ad')

# %%
adata.obsm = ''
adata.write('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/2-RCTD/17s30980&18s18941.016um/17s30980&18s18941.016um.tmp.h5ad')
