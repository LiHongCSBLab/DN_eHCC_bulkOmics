# %%
library(reticulate)
library(Seurat)
library(anndata)
library(sceasy)

# Convert h5ad to Seurat object
seurat_obj <- convertFormat("/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/2-RCTD/17s30980&18s18941.016um/17s30980&18s18941.016um.tmp.h5ad", from = "anndata", to = "seurat")

# Save the Seurat object as an RDS file (optional)
saveRDS(seurat_obj, file = "/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/2-RCTD/17s30980&18s18941.016um/17s30980&18s18941.016um.rds")
# Out:
# Attaching SeuratObject
#
# X -> counts
