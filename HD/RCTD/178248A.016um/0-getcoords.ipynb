# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
adata = sc.read('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/0-Rawh5ad/178248A.016um.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 77526 × 18085
#     obs: 'in_tissue', 'array_row', 'array_col', 'pxl_row_in_fullres', 'pxl_col_in_fullres', 'index'
#     var: 'gene_ids', 'feature_types', 'genome'
#     obsm: 'spatial'

# %%
adata.obsm['spatial']
# Out:
# array([[10238.62608338,  3283.27810485],
#        [ 7906.6804881 , 20015.66668971],
#        [12056.56989938, 21959.36541786],
#        ...,
#        [ 3096.1730462 ,  3906.03615607],
#        [ 6044.95179796, 16205.79307493],
#        [12999.58917619, 19738.04473888]])

# %%
(pd.DataFrame(adata.obsm['spatial'],columns = ['x','y'],index = adata.obs.index)).to_csv('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/2-RCTD/178248A.016um/178248A.016um.coords.csv')
