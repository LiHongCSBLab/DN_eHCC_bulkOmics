# %%
library(reticulate)
library(Seurat)
library(anndata)
library(sceasy)
# Out:
# Attaching SeuratObject

# %%
# Convert h5ad to Seurat object
seurat_obj <- convertFormat("/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/0-Rawh5ad/178248A.016um.tmp.h5ad", from = "anndata", to = "seurat")

# Save the Seurat object as an RDS file (optional)
saveRDS(seurat_obj, file = "/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/2-RCTD/178248A.016um/178248A.016um.rds")
# Out:
# X -> counts
