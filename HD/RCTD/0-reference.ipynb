# %%
library(Seurat)
# Out:
# Attaching SeuratObject
#
# Seurat v4 was just loaded with SeuratObject v5; disabling v5 assays and
# validation routines, and ensuring assays work in strict v3/v4
# compatibility mode

# %%
ref = readRDS('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/2-RCTD/v2/scRNA_ref.rds')

# %%
ref
# Out:
# An object of class Seurat
# 36601 features across 245920 samples within 1 assay
# Active assay: RNA (36601 features, 0 variable features)
#  2 layers present: counts, data
#  1 dimensional reduction calculated: doublet_detection

# %%
str(ref)
# Out:
# Formal class 'Seurat' [package "SeuratObject"] with 13 slots
#   ..@ assays      :List of 1
#   .. ..$ RNA:Formal class 'Assay' [package "SeuratObject"] with 8 slots
#   .. .. .. ..@ counts       :Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#   .. .. .. .. .. ..@ i       : int [1:544927679] 413 482 500 559 683 726 744 754 804 1076 ...
#   .. .. .. .. .. ..@ p       : int [1:245921] 0 331 2030 2408 4121 4492 6084 8358 10965 11550 ...
#   .. .. .. .. .. ..@ Dim     : int [1:2] 36601 245920
#   .. .. .. .. .. ..@ Dimnames:List of 2
#   .. .. .. .. .. .. ..$ : chr [1:36601] "MIR1302-2HG" "FAM138A" "OR4F5" "AL627309.1" ...
#   .. .. .. .. .. .. ..$ : chr [1:245920] "AAACCCAAGGTAAGAG-1-P1_T" "AAACCCAAGTAGGAAG-1-P1_T" "AAACCCACACGACGAA-1-P1_T" "AAACCCACATTGAAAG-1-P1_T" ...
#   .. .. .. .. .. ..@ x       : num [1:544927679] 1 1 1 1 1 1 1 1 2 1 ...
#   .. .. .. .. .. ..@ factors : list()
#   .. .. .. ..@ data         :Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
# ...

# %%
unique(ref@meta.data['cellType'])
# Out:
#                         cellType
# AAACCCAAGGTAAGAG-1-P1_T Neutrophil
# AAACCCAAGTAGGAAG-1-P1_T CAF
# AAACCCACATTGAAAG-1-P1_T Tumor
# AAACGAAAGTGCTAGG-1-P1_T CD4T
# AAACGAAAGTTCAACC-1-P1_T Macrophage
# AAACGAACAGTCAGCC-1-P1_T Endothelial
# AAACGCTAGTGATCGG-1-P1_T CD8T
# AACCACAGTGTTATCG-1-P1_T Smooth muscle
# AAGCGAGGTATCAAGA-1-P1_T DC
# ATCACGACAGTTGCGC-1-P2_T B cell

# %%
table(ref@meta.data['cellType'])
# Out:
# cellType
#        B cell           CAF          CD4T          CD8T            DC
#          6590          6789         38744         40307          4311
#   Endothelial    Macrophage    Neutrophil Smooth muscle         Tumor
#         34541         47200         11687          2741         53010

# %%
# 获取要保留的细胞名称
cells_to_keep <- rownames(ref@meta.data)[!ref@meta.data$cellType %in% c('DC')]

# 创建子集
subset_ref <- ref[, cells_to_keep]

# %%
subset_ref
# Out:
# An object of class Seurat
# 36601 features across 241609 samples within 1 assay
# Active assay: RNA (36601 features, 0 variable features)
#  2 layers present: counts, data
#  1 dimensional reduction calculated: doublet_detection

# %%
Idents(subset_ref) = subset_ref$cellType

# %%
# subset_ref <- RenameIdents(subset_ref, "NK/T" = "NKT")

# %%
unique(subset_ref@meta.data['cellType'])
# Out:
#                         cellType
# AAACCCAAGGTAAGAG-1-P1_T Neutrophil
# AAACCCAAGTAGGAAG-1-P1_T CAF
# AAACCCACATTGAAAG-1-P1_T Tumor
# AAACGAAAGTGCTAGG-1-P1_T CD4T
# AAACGAAAGTTCAACC-1-P1_T Macrophage
# AAACGAACAGTCAGCC-1-P1_T Endothelial
# AAACGCTAGTGATCGG-1-P1_T CD8T
# AACCACAGTGTTATCG-1-P1_T Smooth muscle
# ATCACGACAGTTGCGC-1-P2_T B cell

# %%
unique(Idents(subset_ref))
# Out:
#  [1] Neutrophil    CAF           Tumor         CD4T          Macrophage
#  [6] Endothelial   CD8T          Smooth muscle DC            B cell
# 10 Levels: Neutrophil CAF Tumor CD4T Macrophage Endothelial ... B cell

# %%
saveRDS(subset_ref,'/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/2-RCTD/scRNA_ref.rds')
