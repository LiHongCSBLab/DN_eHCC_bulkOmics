# %%
import numpy as np
import pandas as pd

# %%
samples = ['17s30980_DN','18s18941_DN','178248A_DN','18s18941_t2_DN',
          '17s30980_Tumor','18s18941_Tumor','178248A_Tumor','18s18941_t2_Tumor']
savepath = '/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/test/SOAPy/CCC_csv/'

# %%
output = {}

# %%
for sample in samples:

    df1 = pd.read_csv(savepath+f'{sample}_contact_affinity.csv',index_col=0)
    df2 = pd.read_csv(savepath+f'{sample}_contact_strength.csv',index_col=0)
    df3 = pd.read_csv(savepath+f'{sample}_secretory_affinity.csv',index_col=0)
    df4 = pd.read_csv(savepath+f'{sample}_secretory_strength.csv',index_col=0)

    tmp1 = df2[(df1 <0.05) & (df2 >2)]
    tmp2 = df4[(df3 <0.05) & (df4 >2)]
    res1 = [f"{row},{col}" for row, col in tmp1.stack().index.tolist()]
    res2 = [f"{row},{col}" for row, col in tmp2.stack().index.tolist()]
    output[sample] = res1+res2

# %%
df = pd.DataFrame(list(output.items()), columns=['sample', 'LR'])
df.to_csv('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/test/SOAPy/CCC_csv/filter/CCC.strength2.p0.05.csv', index=False)

# %%
df.index = df['sample']

# %%
df
# Out:
#                               sample  \
# sample
# 17s30980_DN              17s30980_DN
# 18s18941_DN              18s18941_DN
# 178248A_DN                178248A_DN
# 18s18941_t2_DN        18s18941_t2_DN
# 17s30980_Tumor        17s30980_Tumor
# 18s18941_Tumor        18s18941_Tumor
# 178248A_Tumor          178248A_Tumor
# 18s18941_t2_Tumor  18s18941_t2_Tumor
#
#                                                                   LR
# sample
# 17s30980_DN        [COL1A1:ITGA1&ITGB1,CAF_Hepatocyte, COL1A1:ITG...
# 18s18941_DN        [COL1A1:ITGA1&ITGB1,CAF_Hepatocyte, COL1A1:ITG...
# 178248A_DN         [COL4A2:ITGA1&ITGB1,CAF_Endothelial, COL6A2:IT...
# 18s18941_t2_DN     [COL6A1:ITGA1&ITGB1,Smooth muscle_Hepatocyte, ...
# 17s30980_Tumor     [COL1A1:ITGA1&ITGB1,CAF_CAF, COL1A1:ITGA1&ITGB...
# 18s18941_Tumor     [COL1A1:ITGA1&ITGB1,CAF_B cell, COL1A1:ITGA1&I...
# 178248A_Tumor      [FN1:ITGA4&ITGB1,B cell_CAF, FN1:ITGA5&ITGB1,H...
# 18s18941_t2_Tumor  [COL1A2:ITGA1&ITGB1,CD4T_CAF, COL1A2:ITGA1&ITG...

# %%
a = list((set(df.loc['17s30980_Tumor','LR'])-set(df.loc['17s30980_DN','LR'])) & (set(df.loc['18s18941_Tumor','LR'])-set(df.loc['18s18941_DN','LR'])))

# %%
pd.DataFrame(a).to_csv('/csb2/finishedProject/HuiLiJian_DN_2025/10x_HD/5-final/test/SOAPy/CCC_csv/filter/LR.csv')
